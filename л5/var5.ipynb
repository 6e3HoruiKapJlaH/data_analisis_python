# %%
# %matplotlib inline
import pandas as pd
import  numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv("Amazon.csv")
data['Date'] = pd.to_datetime(data['Date'])
data.set_index(keys='Date', inplace=True)

data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  5842.000000  5842.000000  5842.000000  5842.000000  5842.000000
# mean    372.707174   376.921392   368.114569   372.746660   372.746660
# std     585.571802   591.766458   578.660700   585.607655   585.607655
# min       1.406250     1.447917     1.312500     1.395833     1.395833
# 25%      37.955001    38.547501    37.207500    37.927499    37.927499
# 50%      83.428749    84.945000    81.656250    83.459999    83.459999
# 75%     359.729988   363.439987   356.280006   360.047501   360.047501
# max    3251.060059  3344.290039  3151.000000  3200.000000  3200.000000
#
#              Volume
# count  5.842000e+03
# mean   7.519048e+06
# std    7.282683e+06
# min    4.872000e+05
# 25%    3.684900e+06
# 50%    5.657200e+06
# 75%    8.533400e+06
# max    1.043292e+08

# %%
data['Close'].plot()
plt.title('Amazon Stock Price')
# Out:
# Text(0.5, 1.0, 'Amazon Stock Price')

# %%
data.loc['2018-01-01':'2018-12-31', ['Close']].plot()
plt.title('Amazon Stock Price in 2018')
# Out:
# Text(0.5, 1.0, 'Amazon Stock Price in 2018')

# %%
data.loc['2020-01-01':'2020-02-01', ['Close']].plot()
plt.title('Amazon Stock Price in January 2020')
# Out:
# Text(0.5, 1.0, 'Amazon Stock Price in January 2020')

# %%
data.loc['2016-12-01':'2018-03-01', ['Close']].plot()
plt.title('Amazon Stock Price 2016-2018')
# Out:
# Text(0.5, 1.0, 'Amazon Stock Price 2016-2018')

# %%
data.loc['2016-01-01':'2018-01-01', ['Close']].plot()
plt.title('Amazon Stock Price 2016-2018')
# Out:
# Text(0.5, 1.0, 'Amazon Stock Price 2016-2018')

# %%
data.loc['2016-01-01':'2016-12-31', ['High']].resample('D').max().plot()
plt.title('Daily Highs in 2016')
# Out:
# Text(0.5, 1.0, 'Daily Highs in 2016')

# %%
data.loc[:, ['High']].resample('D').max().plot()
plt.title('Daily Highs')
# Out:
# Text(0.5, 1.0, 'Daily Highs')

# %%
data.loc['2019-03-01':'2019-05-31', ['High']].resample('W').max().plot()
plt.title('Weekly Highs in 2019')
# Out:
# Text(0.5, 1.0, 'Weekly Highs in 2019')

# %%
data.loc['2018-03-01':'2018-05-31', ['High']].pct_change().plot()
plt.title('Daily Highs in 2018')
# Out:
# Text(0.5, 1.0, 'Daily Highs in 2018')

# %%
data.loc['2017-01-01':'2017-12-31', ['High']].rolling(window=60).mean().plot()
plt.title('60 Day Rolling Average of Daily Highs in 2017')
# Out:
# Text(0.5, 1.0, '60 Day Rolling Average of Daily Highs in 2017')
